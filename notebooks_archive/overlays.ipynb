# %%
# People in Regionalverband Braunschweig
import pandas as pd
gem = pd.read_parquet(r"C:\Users\petre\PycharmProjects\cleancensus\with_gender\cells_100m_with_gender_backfilled_100_4.parquet")
kreise = {"01","02","03","51","53","54","57","58"}  # adjust if needed
mask = (gem["Land"]=="03") & (gem["Regierungsbezirk"]=="1") & (gem["Kreis"].isin(kreise))
total_pop = float(gem.loc[mask, "POP_TOTAL_100m_adj"].sum())
total_pop
# Out:
# 1130938.8429210458
